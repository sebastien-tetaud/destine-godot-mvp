# %%
import sys
import os
sys.path.append('../src/util/')
import numpy as np
import pandas as pd

from general import (IGNLidarProcessor, Sentinel2Reader,
                     load_dem_utm, PcdGenerator,
                     PointCloudHandler, PcdFilter)

# %%
input_file = "../src/dem-data/LHD_FXX_0982_6524_PTS_C_LAMB93_IGN69.copc.laz"
sample_fraction = 0.2

processor = IGNLidarProcessor(input_file)
processor.read_point_cloud()
processor.transform_coordinates()
processor.downsample(sample_fraction=sample_fraction)
processor.generate_color()
df_ign = processor.df
df_ign.head()
# Out:
# Point cloud downsampled with sample fraction 0.2
#                       x             y        z  classification           color
# 259626    315601.754841  5.069443e+06  1603.25               3  (31, 119, 180)
# 2419389   315617.506961  5.069177e+06  1677.62               5  (255, 127, 14)
# 17900936  315742.764659  5.069129e+06  1720.02               5  (255, 127, 14)
# 3666107   315680.390416  5.069146e+06  1699.57               5  (255, 127, 14)
# 20740605  315874.449597  5.069438e+06  1800.28               2   (214, 39, 40)

# %%
token = os.environ.get('hdb_token')
product_path = "/home/ubuntu/project/destine-godot-mvp/src/sentinel2-data/T32TLR_20241030T103151_TCI_20m.jp2"
reader = Sentinel2Reader(filepath=product_path, preprocess=True)
bounds = reader.bounds
width = reader.width
height = reader.height
parameter = 'dem'

# %%
dem_data = load_dem_utm(token, parameter, bounds, width, height)
# Initialize and generate point cloud
pcd_gen = PcdGenerator(sat_data=reader.data,
                       dem_data=dem_data,
                       sample_fraction=sample_fraction)
pcd_gen.generate_point_cloud()
# pcd_gen.downsample(sample_fraction=sample_fraction)
df = pcd_gen.df
df.head()
# Out:
# Total points before sampling: 30140100
#         x        y         z            color
# 0  300010  4990210  2474.875    (116, 95, 79)
# 1  300030  4990210  2468.250    (112, 91, 73)
# 2  300050  4990210  2459.250   (128, 107, 88)
# 3  300070  4990210  2448.500   (139, 113, 94)
# 4  300090  4990210  2435.250  (143, 123, 104)

# %%
filterer = PcdFilter(df=df, df_target=df_ign)
filterer.set_bounding_box_from_target(margin=4)
df_filtered = filterer.filter_data()
pcd = filterer.concatenate_dataframes([df_filtered, df_ign])

# %%
handler = PointCloudHandler(pcd)
handler.to_open3d()
handler.save_point_cloud(filename="final_IGN_LiDAR_HD.ply")
# Out:
# Point cloud saved to final_IGN_LiDAR_HD.ply

# %%
import folium
from pyproj import Transformer

# Initialize transformer to convert UTM (EPSG:32632) to WGS84 (EPSG:4326)
transformer_to_wgs84 = Transformer.from_crs("epsg:32632", "epsg:4326", always_xy=True)

def get_bbox_coordinates(df):
    """Calculate bounding box (min/max) and convert UTM to WGS84."""
    x_min, x_max = df["x"].min(), df["x"].max()
    y_min, y_max = df["y"].min(), df["y"].max()

    lat_min, lon_min = transformer_to_wgs84.transform(x_min, y_min)
    lat_max, lon_max = transformer_to_wgs84.transform(x_max, y_max)
    return (lat_min, lon_min), (lat_max, lon_max), transformer_to_wgs84.transform((x_min + x_max) / 2, (y_min + y_max) / 2)

# Get bounding boxes and map center
bbox1_min, bbox1_max, center1 = get_bbox_coordinates(df)
bbox2_min, bbox2_max, center2 = get_bbox_coordinates(df_ign)

# Define map center as the midpoint between the two dataset centers
map_center = [(center1[1] + center2[1]) / 2, (center1[0] + center2[0]) / 2]

# Initialize Folium map
m = folium.Map(location=map_center, zoom_start=8, tiles='OpenStreetMap')

# Add first bounding box (df)
folium.Rectangle(
    bounds=[bbox1_min[::-1], bbox1_max[::-1]],  # Reverse (lat, lon) order
    color="blue",
    weight=2,
    fill=True,
    fill_opacity=0.3,
    popup="Sentinel 2"
).add_to(m)

# Add second bounding box (df_ign)
folium.Rectangle(
    bounds=[bbox2_min[::-1], bbox2_max[::-1]],  # Reverse (lat, lon) order
    color="red",
    weight=2,
    fill=True,
    fill_opacity=0.3,
    popup="IGN "
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dce720ec98f53c5b7045ba403c6068c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dce720ec98f53c5b7045ba403c6068c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dce720ec98f53c5b7045ba403c6068c = L.map(
#                 &quot;map_4dce720ec98f53c5b7045ba403c6068c&quot;,
#                 {
#                     center: [45.64848637653778, 6.888285971400045],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b6291c3ec910e8887d53ab6a3609607 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b6291c3ec910e8887d53ab6a3609607.addTo(map_4dce720ec98f53c5b7045ba403c6068c);
#
#
#             var rectangle_12c3dc991dccf10d891b5bec2aca7028 = L.rectangle(
#                 [[45.037115868274746, 6.4609086491762096], [46.04771892484105, 7.834235425747837]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_4dce720ec98f53c5b7045ba403c6068c);
#
#
#         var popup_97817aeb367fe15dbd89682b2145553a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c4ef8286069c3700a68f27747d74911 = $(`&lt;div id=&quot;html_1c4ef8286069c3700a68f27747d74911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sentinel 2&lt;/div&gt;`)[0];
#                 popup_97817aeb367fe15dbd89682b2145553a.setContent(html_1c4ef8286069c3700a68f27747d74911);
#
#
#
#         rectangle_12c3dc991dccf10d891b5bec2aca7028.bindPopup(popup_97817aeb367fe15dbd89682b2145553a)
#         ;
#
#
#
#
#             var rectangle_7410f2992519e0894fd8e682444af89e = L.rectangle(
#                 [[45.74759581817695, 6.628459408057417], [45.75753584660895, 6.641838624031994]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_4dce720ec98f53c5b7045ba403c6068c);
#
#
#         var popup_d9789ebcd604a8ddf0a2fc4e1bdf81fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_845ac42c39aa6ee617b8c00fbe5c890b = $(`&lt;div id=&quot;html_845ac42c39aa6ee617b8c00fbe5c890b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IGN &lt;/div&gt;`)[0];
#                 popup_d9789ebcd604a8ddf0a2fc4e1bdf81fb.setContent(html_845ac42c39aa6ee617b8c00fbe5c890b);
#
#
#
#         rectangle_7410f2992519e0894fd8e682444af89e.bindPopup(popup_d9789ebcd604a8ddf0a2fc4e1bdf81fb)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filterer = PcdFilter(df=df, df_target=df_ign)
filterer.set_bounding_box_from_target(margin=6)
df_filtered = filterer.filter_data()
pcd = filterer.concatenate_dataframes([df_filtered, df_ign])

# %%
handler = PointCloudHandler(pcd)
handler.to_open3d()
handler.save_point_cloud(filename="IGN_LiDAR_HD.ply")
# Out:
# Point cloud saved to IGN_LiDAR_HD.ply

# %% [markdown]
# ## Process all the data for a given Tile

# %%
import geopandas as gpd

shapefile_path = "/home/ubuntu/project/destine-godot-mvp/src/ign-resources/TA_diff_pkk_lidarhd_classe.shp"
# Load the shapefile into a GeoDataFrame
gdf = gpd.read_file(shapefile_path)
gdf.head()
# Out:
#                                          nom_pkk  \
# 0  LHD_FXX_0230_6852_PTS_C_LAMB93_IGN69.copc.laz
# 1  LHD_FXX_0232_6870_PTS_C_LAMB93_IGN69.copc.laz
# 2  LHD_FXX_0187_6874_PTS_C_LAMB93_IGN69.copc.laz
# 3  LHD_FXX_0196_6839_PTS_C_LAMB93_IGN69.copc.laz
# 4  LHD_FXX_0229_6846_PTS_C_LAMB93_IGN69.copc.laz
#
#                                           url_telech  \
# 0  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 1  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 2  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 3  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 4  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
#
#                                             geometry
# 0  POLYGON ((230000 6851000, 230000 6852000, 2310...
# 1  POLYGON ((232000 6869000, 232000 6870000, 2330...
# 2  POLYGON ((187000 6873000, 187000 6874000, 1880...
# 3  POLYGON ((196000 6838000, 196000 6839000, 1970...
# 4  POLYGON ((229000 6845000, 229000 6846000, 2300...

# %%
reader = Sentinel2Reader(filepath=product_path, preprocess=True)
bounds = reader.bounds
from shapely.geometry import box
bounding_box = box(bounds.left, bounds.bottom, bounds.right, bounds.top)

# Create a GeoDataFrame with EPSG:32632 (or your actual UTM zone)
gdf_utm = gpd.GeoDataFrame(geometry=[bounding_box], crs="EPSG:32632")

# Optionally, you can transform to Lambert 93 (EPSG:2154)
gd_lambert = gdf_utm.to_crs(epsg=2154)
gd_lambert
# Out:
#                                             geometry
# 0  POLYGON ((1081873.964 6451770.709, 1073568.628...

# %%
intersection = gdf[gdf.intersects(gd_lambert.geometry.values[0])]
intersection
# Out:
#                                               nom_pkk  \
# 211238  LHD_FXX_0988_6554_PTS_C_LAMB93_IGN69.copc.laz
# 211239  LHD_FXX_1006_6547_PTS_C_LAMB93_IGN69.copc.laz
# 211240  LHD_FXX_0982_6538_PTS_C_LAMB93_IGN69.copc.laz
# 211256  LHD_FXX_0974_6535_PTS_C_LAMB93_IGN69.copc.laz
# 211258  LHD_FXX_0978_6541_PTS_C_LAMB93_IGN69.copc.laz
# ...                                               ...
# 242928  LHD_FXX_0998_6471_PTS_C_LAMB93_IGN69.copc.laz
# 242929  LHD_FXX_1004_6466_PTS_C_LAMB93_IGN69.copc.laz
# 242930  LHD_FXX_1022_6471_PTS_C_LAMB93_IGN69.copc.laz
# 242931  LHD_FXX_0998_6462_PTS_C_LAMB93_IGN69.copc.laz
# 242932  LHD_FXX_0989_6474_PTS_C_LAMB93_IGN69.copc.laz
#
#                                                url_telech  \
# 211238  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 211239  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 211240  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 211256  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 211258  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# ...                                                   ...
# 242928  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 242929  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 242930  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 242931  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
# 242932  https://storage.sbg.cloud.ovh.net/v1/AUTH_6323...
#
#                                                  geometry
# 211238  POLYGON ((988000 6553000, 988000 6554000, 9890...
# 211239  POLYGON ((1006000 6546000, 1006000 6547000, 10...
# 211240  POLYGON ((982000 6537000, 982000 6538000, 9830...
# 211256  POLYGON ((974000 6534000, 974000 6535000, 9750...
# 211258  POLYGON ((978000 6540000, 978000 6541000, 9790...
# ...                                                   ...
# 242928  POLYGON ((998000 6470000, 998000 6471000, 9990...
# 242929  POLYGON ((1004000 6465000, 1004000 6466000, 10...
# 242930  POLYGON ((1022000 6470000, 1022000 6471000, 10...
# 242931  POLYGON ((998000 6461000, 998000 6462000, 9990...
# 242932  POLYGON ((989000 6473000, 989000 6474000, 9900...
#
# [4719 rows x 3 columns]

# %%
# Transform the coordinates from EPSG:2154 to EPSG:4326 (WGS 84)
gdf_wgs84 = intersection.to_crs(epsg=4326)

def get_bbox_coordinates(df):
    """Calculate bounding box (min/max) and convert UTM to WGS84."""
    x_min, x_max = df["x"].min(), df["x"].max()
    y_min, y_max = df["y"].min(), df["y"].max()

    lat_min, lon_min = transformer_to_wgs84.transform(x_min, y_min)
    lat_max, lon_max = transformer_to_wgs84.transform(x_max, y_max)
    return (lat_min, lon_min), (lat_max, lon_max), transformer_to_wgs84.transform((x_min + x_max) / 2, (y_min + y_max) / 2)

# Get bounding boxes and map center
bbox1_min, bbox1_max, center1 = get_bbox_coordinates(df)
bbox2_min, bbox2_max, center2 = get_bbox_coordinates(df_ign)

# Define map center as the midpoint between the two dataset centers
map_center = [(center1[1] + center2[1]) / 2, (center1[0] + center2[0]) / 2]

# Initialize Folium map
m = folium.Map(location=map_center, zoom_start=8, tiles='OpenStreetMap')

# Add first bounding box (df)
folium.Rectangle(
    bounds=[bbox1_min[::-1], bbox1_max[::-1]],  # Reverse (lat, lon) order
    color="Red",
    weight=2,
    fill=True,
    fill_opacity=0.3,
    popup="Sentinel 2"
).add_to(m)

# Loop through each geometry in your gdf_wgs84 and add its bounding box to the map
for _, row in gdf_wgs84.iterrows():
    # Get the bounding box coordinates (minx, miny, maxx, maxy) in EPSG:4326
    minx, miny, maxx, maxy = row['geometry'].bounds

    # Create a bounding box as a polygon in Folium (latitude, longitude)
    folium.Rectangle(
        bounds=[[miny, minx], [maxy, maxx]],  # (southwest, northeast)
        color="blue",  # Set the color of the bounding box
        weight=2,  # Set the line thickness
        fill=True,  # Whether the bounding box should be filled
        fill_opacity=0.2  # Set the fill opacity
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ec1c1ed8ef51ea2ea6c76b4087afb13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ec1c1ed8ef51ea2ea6c76b4087afb13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ec1c1ed8ef51ea2ea6c76b4087afb13 = L.map(
#                 &quot;map_7ec1c1ed8ef51ea2ea6c76b4087afb13&quot;,
#                 {
#                     center: [45.64848637653778, 6.888285971400045],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e464f5f490727fca94cd9dff8a78b2a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e464f5f490727fca94cd9dff8a78b2a.addTo(map_7ec1c1ed8ef51ea2ea6c76b4087afb13);
#
#
#             var rectangle_dd19c2d29e664abc614b0fe1e538184b = L.rectangle(
#                 [[45.037115868274746, 6.4609086491762096], [46.04771892484105, 7.834235425747837]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;Red&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_7ec1c1ed8ef51ea2ea6c76b4087afb13);
#
#
#         var popup_d0a875008201612cae46f6c825a454c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96c6ec62db3bfb01e0b3aec061247b8d = $(`&lt;div id=&quot;html_96c6ec62db3bfb01e0b3aec061247b8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sentinel 2&lt;/div&gt;`)[0];
#                 popup_d0a875008201612cae46f6c825a454c9.setContent(html_96c6ec62db3bfb01e0b3aec061247b8d);
#
#
#
#         rectangle_dd19c2d29e664abc614b0fe1e538184b.bindPopup(popup_d0a875008201612cae46f6c825a454c9)
#         ;
#
#
#
#
#             var rectangle_2c0a19bf8c32fdf5d60e3d9641a46081 = L.rectangle(
#                 [[46.01519061271429, 6.723705541557834], [46.024610749735146, 6.7372272985011366]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_7ec1c1ed8ef51ea2ea6c76b4087afb13);
#
#
#             var rectangle_34f237fb17c048394edb679aff7a8c37 = L.rectangle(
#                 [[45.94433004775926, 6.951534276141269], [45.95377488166064, 6.965074031741652]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_7ec1c1ed8ef51ea2ea6c76b4087afb13);
#
#
#             var rectangle_0553c8eadd99c42ebfc3767834d0a6ce = L.rectangle(
#                 [[45.87379540251174, 6.636718424440973], [45.883206095396886, 6.650191985726956]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_7ec1c1ed8ef51ea2ea6c76b4087afb13);
#
#
#             var rectangle_ab115471d86afdd59a4a11194d56218c = L.rectangle(
#                 [[45.850089355306515, 6.531959367731455], [45.85948865095817, 6.545410834780762]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;,
